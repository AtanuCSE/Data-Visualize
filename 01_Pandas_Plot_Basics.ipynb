# %% [markdown]
# # **Pandas Plot Basics**

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'Price.csv')
print(df)
# Out:
#    Month  Item  Money
# 0    Jan     5    135
# 1    Feb    52    280
# 2    Mar    50     91
# 3    Apr    28    282
# 4    May    26    117
# 5    Jun    20     38
# 6    Jul    52    275
# 7    Aug    19    225
# 8    Sep    48    189
# 9    Oct    48     40
# 10   Nov     9     42
# 11   Dec    25    214

# %% [markdown]
# Statistics

# %%
print(df.describe())
# Out:
#             Item       Money
# count  12.000000   12.000000
# mean   31.833333  160.666667
# std    17.340616   95.787960
# min     5.000000   38.000000
# 25%    19.750000   78.750000
# 50%    27.000000  162.000000
# 75%    48.500000  237.500000
# max    52.000000  282.000000

# %% [markdown]
# Plot

# %%
df.plot(x='Month', y='Item')
df.plot(x='Month', y='Money')
plt.show()
